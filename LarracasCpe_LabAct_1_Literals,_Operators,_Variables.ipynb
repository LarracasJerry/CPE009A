# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/LarracasCpe_LabAct_1_Literals%2C_Operators%2C_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Activity 1: Literals, Operators, and Variables

# %%
value = 5
type(value)
# Out:
# int

# %%
value = 5.0
type(value)
# Out:
# float

# %% [markdown]
# a. 2+3j

# %%
value = 2 + 3j
type(value)
# Out:
# complex

# %% [markdown]
# b. 'Hello World'

# %%
value = 'Hello World'
type(value)
# Out:
# str

# %% [markdown]
# c. “Hello World”

# %%
value = "Hello World"
type(value)
# Out:
# str

# %% [markdown]
# d. True

# %%
value = True
type(value)
# Out:
# bool

# %% [markdown]
# e. False

# %%
value = False
type(value)
# Out:
# bool

# %% [markdown]
# f. [1,2,3,4,5]

# %%
value = [1,2,3,4,5]
type(value)
# Out:
# list

# %% [markdown]
# g. (1,2,3,4,5)

# %%
value = (1,2,3,4,5)
type(value)
# Out:
# tuple

# %% [markdown]
# h. {'name': 'Your_name'}

# %%
value = {'name': 'Your_name'}
type(value)
# Out:
# dict

# %% [markdown]
# i. None

# %%
value = None
type(value)
# Out:
# NoneType

# %% [markdown]
# 6. Re-assign the value variable to be equal to 5.

# %%
value = 5

# %% [markdown]
# 7. Declare a new variable named value2 to be equal to -6.

# %%
value2 = -6

# %% [markdown]
# Performing Operations with Python

# %%
print(value+value2)
# Out:
# -1

# %%
value, value2 = 5.0, 6
print(value+value2)
# Out:
# 11.0

# %%
value, value2 = -5, 6.1
print(value+value2)
# Out:
# 1.0999999999999996

# %%
value, value2 = "Hello",' world'
print(value+value2)
# Out:
# Hello world

# %%
value, value2 = [1,2,3], [4,5,6]
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
value, value2 = (1,2,3), (4,5,6)
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
value, value2 = {"name" :"Royce"},{"age":2}
print(value | value2)
# Out:
# {'name': 'Royce', 'age': 2}

# %% [markdown]
# 3. Using value, value2 = 30, 4

# %%
value, value2 = 30, 4
print(value*value2)
# Out:
# 120

# %%
print(value2**2)
# Out:
# 16

# %%
print(value2**3)
# Out:
# 64

# %%
print(value*value2+value2**2+1)
# Out:
# 137

# %%
print(value/value2)
# Out:
# 7.5

# %%
print(value%value2)
# Out:
# 2

# %% [markdown]
# Receiving Input Data using Python

# %%
input("Message Name ")
# Out:
# Message Name Larracas
# 'Larracas'

# %%
name = input("Enter youe name: ")
# Out:
# Enter youe name: Jerry

# %% [markdown]
# Assigning Input Data to a Variable

# %%
name = input("Enter your name: ")
name = str(name)
weight = input("Enter your weight(kg): ")
weight = float(weight)
height = input("Enter your height(m): ")
height = float(height)
# Out:
# Enter your name: Larracas
# Enter your weight(kg): 65.4
# Enter your height(m): 1.6

# %%
bmi = weight / height **2
print(bmi)
# Out:
# 25.546874999999996

# %%
print("Name:", name, "\nWeight:", weight, "\nHeight:",height, "\nBMI:", bmi)
# Out:
# Name: Larracas
# Weight: 65.4
# Height: 1.6
# BMI: 25.546874999999996

# %% [markdown]
# Supplementary Activity:

# %%
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = 1/2 * base*height
print("The area of the triangle is", area)
# Out:
# Enter the base of the triangle: 5
# Enter the height of the triangle: 8
# The area of the triangle is 20.0

# %% [markdown]
# 2. Convert Celsius to Fahrenheit

# %%
celsius = float(input("Enter the celsius you want to convert: "))
fahrenheit = (celsius*9/5) + 32
print("0C = ", fahrenheit)
# Out:
# Enter the celsius you want to convert: 0
# 0C =  32.0

# %%
celsius = float(input("Enter the celsius you want to convert: "))
fahrenheit = (celsius*9/5) + 32
print("-20C = ", fahrenheit)
# Out:
# Enter the celsius you want to convert: -20
# -20C =  -4.0

# %% [markdown]
# 3. Write a program that can determine the distance between two points given the coordinates using the formula:

# %%
x1 = float(input("Enter x1: "))
x2 = float(input("Enter x2: "))
y1 = float(input("Enter y1: "))
y2 = float(input("Enter y2: "))

d = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
print("\nTherefore the distance between two points is ",d)
# Out:
# Enter x1: 2
# Enter x2: -3
# Enter y1: 2
# Enter y2: 3
#
# Therefore the distance between two points is  5.0990195135927845
