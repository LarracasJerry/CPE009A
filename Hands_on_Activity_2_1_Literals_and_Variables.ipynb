# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/Hands_on_Activity_2_1_Literals_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: Hands-on Activity 2.1 Literals and Variables</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed: 1/15/2026** |
# | **Section**: CPE12S2  | **Date Submitted: 1/15/2026** |
# | **Student Name**: Larracas, Jerry Matthew  | **Instructor's Name:** Mrs. Sayo, Maria Rizette |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

#1. PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#2. PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment

print("|  Prelim  |")
p_HOA = float(input("Enter Hands-on Activity grade: "))
p_quiz = float(input("Enter Prelim Quiz grade: "))
p_assignment = float(input("Enter Prelim Assignment grade: "))
p_exam = float(input("Enter Prelim Exam grade: "))


p_cs = p_HOA*.5 + p_quiz*.3 + p_assignment*.2
print("\nPrelim Class standing is: ", p_cs)
p_grade = p_exam*.5 + p_cs*.5
print("Prelim Grade is: ", "%.2f" % p_grade)

#3. MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#4. MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment

print("\n|  Midterm  |")
m_HOA = float(input("Enter Hands-on Activity grade: "))
m_quiz = float(input("Enter Midterm Quiz grade: "))
m_assignment = float(input("Enter Midterm Assignment grade: "))
m_exam = float(input("Enter Midterm Exam grade: "))


m_cs = m_HOA*.5 + m_quiz*.3 + m_assignment*.2
print("\nMidterm Class standing is: ", m_cs)
m_grade = (p_grade*(1/3)) + (2/3)*(m_exam*.5 + m_cs*.5)
print("Midterm Grade is: ", "%.2f" % m_grade)

#5.FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#6.FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment

print("\n|  Finals  |")
f_HOA = float(input("Enter Hands-on Activity grade: "))
f_quiz = float(input("Enter Final Quiz grade: "))
f_assignment = float(input("Enter Final Assignment grade: "))
f_exam = float(input("Enter Final Exam grade: "))


f_cs = f_HOA*.5 + f_quiz*.3 + f_assignment*.2
print("\nMidterm Class standing is: ", f_cs)
f_grade = (m_grade*(1/3)) + (2/3)*(f_exam*.5 + f_cs*.5)
print("Final Grade is: ", "%.2f" % f_grade)
# Out:
# |  Prelim  |
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 100
# Enter Prelim Assignment grade: 100
# Enter Prelim Exam grade: 100
#
# Prelim Class standing is:  100.0
# Prelim Grade is:  100.00
#
# |  Midterm  |
# Enter Hands-on Activity grade: 100
# Enter Midterm Quiz grade: 100
# Enter Midterm Assignment grade: 100
# Enter Midterm Exam grade: 100
#
# Midterm Class standing is:  100.0
# Midterm Grade is:  100.00
#
# |  Finals  |
# Enter Hands-on Activity grade: 100
# Enter Final Quiz grade: 100
# Enter Final Assignment grade: 100
# Enter Final Exam grade: 100
#
# Midterm Class standing is:  100.0
# Final Grade is:  100.00

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   Test 3 students from the program you created.
# 2.   The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 3. Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
# Place all the output of the supplementary activity here



#STUDENT #1 GRADE FROM PRELIM TO FINALS AND TIP's NUMERICAL GRADE.
# PRELIM GRADE
print("Enter Name of student#1: \n")
student1 = str(input())

print("|  Prelim  |")
p_HOA = float(input("Enter Hands-on Activity grade: "))
p_quiz = float(input("Enter Prelim Quiz grade: "))
p_assignment = float(input("Enter Prelim Assignment grade: "))
p_exam = float(input("Enter Prelim Exam grade: "))

p_cs = p_HOA*.5 + p_quiz*.3 + p_assignment*.2
print("\nPrelim Class standing is: ", p_cs)
p_grade = p_exam*.5 + p_cs*.5
print("Prelim Grade is: ", "%.2f" % p_grade)

# MIDTERM GRADE
print("\n|  Midterm  |")
m_HOA = float(input("Enter Hands-on Activity grade: "))
m_quiz = float(input("Enter Midterm Quiz grade: "))
m_assignment = float(input("Enter Midterm Assignment grade: "))
m_exam = float(input("Enter Midterm Exam grade: "))

m_cs = m_HOA*.5 + m_quiz*.3 + m_assignment*.2
print("\nMidterm Class standing is: ", m_cs)
m_grade = (p_grade*(1/3)) + (2/3)*(m_exam*.5 + m_cs*.5)
print("Midterm Grade is: ", "%.2f" % m_grade)

# FINAL GRADE
print("\n|  Finals  |")
f_HOA = float(input("Enter Hands-on Activity grade: "))
f_quiz = float(input("Enter Final Quiz grade: "))
f_assignment = float(input("Enter Final Assignment grade: "))
f_exam = float(input("Enter Final Exam grade: "))

f_cs = f_HOA*.5 + f_quiz*.3 + f_assignment*.2
print("\nMidterm Class standing is: ", f_cs)
f_grade = (m_grade*(1/3)) + (2/3)*(f_exam*.5 + f_cs*.5)
print("Final Grade is: ", "%.2f" % f_grade)

#STUDENT #2 GRADE FROM PRELIM TO FINALS AND TIP's NUMERICAL GRADE.
# PRELIM GRADE
print("|  Prelim  |")
p_HOA = float(input("Enter Hands-on Activity grade: "))
p_quiz = float(input("Enter Prelim Quiz grade: "))
p_assignment = float(input("Enter Prelim Assignment grade: "))
p_exam = float(input("Enter Prelim Exam grade: "))

p_cs = p_HOA*.5 + p_quiz*.3 + p_assignment*.2
print("\nPrelim Class standing is: ", p_cs)
p_grade = p_exam*.5 + p_cs*.5
print("Prelim Grade is: ", "%.2f" % p_grade)

# MIDTERM GRADE

print("\n|  Midterm  |")
m_HOA = float(input("Enter Hands-on Activity grade: "))
m_quiz = float(input("Enter Midterm Quiz grade: "))
m_assignment = float(input("Enter Midterm Assignment grade: "))
m_exam = float(input("Enter Midterm Exam grade: "))

m_cs = m_HOA*.5 + m_quiz*.3 + m_assignment*.2
print("\nMidterm Class standing is: ", m_cs)
m_grade = (p_grade*(1/3)) + (2/3)*(m_exam*.5 + m_cs*.5)
print("Midterm Grade is: ", "%.2f" % m_grade)

# FINAL GRADE
print("\n|  Finals  |")
f_HOA = float(input("Enter Hands-on Activity grade: "))
f_quiz = float(input("Enter Final Quiz grade: "))
f_assignment = float(input("Enter Final Assignment grade: "))
f_exam = float(input("Enter Final Exam grade: "))

f_cs = f_HOA*.5 + f_quiz*.3 + f_assignment*.2
print("\nMidterm Class standing is: ", f_cs)
f_grade = (m_grade*(1/3)) + (2/3)*(f_exam*.5 + f_cs*.5)
print("Final Grade is: ", "%.2f" % f_grade)


#STUDENT #3 GRADE FROM PRELIM TO FINALS AND TIP's NUMERICAL GRADE.
# PRELIM GRADE

print("|  Prelim  |")
p_HOA = float(input("Enter Hands-on Activity grade: "))
p_quiz = float(input("Enter Prelim Quiz grade: "))
p_assignment = float(input("Enter Prelim Assignment grade: "))
p_exam = float(input("Enter Prelim Exam grade: "))

p_cs = p_HOA*.5 + p_quiz*.3 + p_assignment*.2
print("\nPrelim Class standing is: ", p_cs)
p_grade = p_exam*.5 + p_cs*.5
print("Prelim Grade is: ", "%.2f" % p_grade)

# MIDTERM GRADE

print("\n|  Midterm  |")
m_HOA = float(input("Enter Hands-on Activity grade: "))
m_quiz = float(input("Enter Midterm Quiz grade: "))
m_assignment = float(input("Enter Midterm Assignment grade: "))
m_exam = float(input("Enter Midterm Exam grade: "))

m_cs = m_HOA*.5 + m_quiz*.3 + m_assignment*.2
print("\nMidterm Class standing is: ", m_cs)
m_grade = (p_grade*(1/3)) + (2/3)*(m_exam*.5 + m_cs*.5)
print("Midterm Grade is: ", "%.2f" % m_grade)

# FINAL GRADE
print("\n|  Finals  |")
f_HOA = float(input("Enter Hands-on Activity grade: "))
f_quiz = float(input("Enter Final Quiz grade: "))
f_assignment = float(input("Enter Final Assignment grade: "))
f_exam = float(input("Enter Final Exam grade: "))

f_cs = f_HOA*.5 + f_quiz*.3 + f_assignment*.2
print("\nMidterm Class standing is: ", f_cs)
f_grade = (m_grade*(1/3)) + (2/3)*(f_exam*.5 + f_cs*.5)
print("Final Grade is: ", "%.2f" % f_grade)


#not finished yet
# Out:
# Enter Name of student#1:
#
# Larracas, Jerry Matthew L.
# |  Prelim  |

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# I have learned more broader knowledge in python language which improves my skill in perfoming a syntax in python, discovered new skills and techniques such as if else statements, computation syntax, how to store values in a certain variable and more. Furthermore, I learned a lot in this lesson and I am proud of myself to able to learn new things.

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25
