# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerry/CPE009A/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 1
a, b, c = 0, 1, 2

b = "sally" #This is a type of string
b = int(4)
print (b)

b = float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or 'Single' quotes

# %%
y = "John"
y = 'John'
print (y)
# Out:
# John

# %% [markdown]
# Case sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a, A)
# Out:
# 4 Sally

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one","two","three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x=y=z= "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Python programming is "+x)
# Out:
# Python programming is enjoying

# %%
x = "Python is "
y = "enjoying"
z = x + y
print (z)
# Out:
# Python is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
10 // 3
# Out:
# 3

# %%
x = 5
y = 3

print (x+y)
x = 5
y = 3

print (x/y)
x = 5
y = 3

print (x*y)
x = 5
y = 3

print (x-y)
x = 5
y = 3

print (x%y)
x = 5
y = 3

print (x**y)
x = 5
y = 3

print (x//y)
x = 5
y = 3

x = 5
y = 3
sum = x + y
sum

x = 5
y = 3
division = x / y
division

x = 5
y = 3
multiply = x * y
multiply

x = 5
y = 3
subtract = x - y
subtract

x = 5
y = 3
Modulus = x % y
Modulus

x = 5
y = 3
Exponent = x ** y
Exponent

x = 5
y = 3
FloorDivision = x // y
FloorDivision
# Out:
# 8
# 1.6666666666666667
# 15
# 2
# 2
# 125
# 1
# 1

# %% [markdown]
# Assignment Operators

# %%
x = 1
x += 3
print(x)

x = 1
x -= 3
print(x)

x = 1
x *= 3
print(x)

x = 1
x /= 1
print(x)

x = 1
x %= 12
print(x)

x = 1
x //= 1
print(x)

x = 1
x **= 3
print(x)

x = 1
x |= 3
print(x)

x = 1
x >>= 3
print(x)

x = 1
x **= 3
print(x)
# Out:
# 4
# -2
# 3
# 1.0
# 1
# 1
# 1
# 3
# 0
# 1

# %% [markdown]
# Comparizon Operators

# %%
t, u = 1, 2

print(x == y)
print(x != y)
print(x >= y)
print(x <= y)
print(x >= y)
print(x <=y )
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# Logical Operators

# %%
x < 5 and x < 10
# Out:
# True

# %%
x < 5 or x < 10
# Out:
# True

# %%
not(x < 5 and x < 10)
# Out:
# False

# %% [markdown]
# Identity Operators

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
v = 2
v << 2
# Out:
# 8

# %%
v = 2
v  & 1
# Out:
# 0

# %%
v = 2
v | 1
# Out:
# 3

# %%
v = 2
v ^ 1
# Out:
# 3

# %%
v = 2
~v
# Out:
# -3

# %%
v = 2
v >> 1
# Out:
# 1
