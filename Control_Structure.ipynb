# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Control Structure

# %%
#Sequential Statements

a=20
b=10
c=a-b
print("Subtraction is:",c)
# Out:
# Subtraction is: 10

# %% [markdown]
# Selection/Decision control statements

# %%
#IF STATEMENTS

a = 12
b = 100
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
#ELIF STATEMENTS

a = 12
b = 12
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
#ELSE STATEMENTS

a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
#SHORT HAND IF STATEMENTS

if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
#SHORT HAND IF ELSE STATEMENTS

a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %%
#AND=BOTH CONDITIONS ARE TRUE

a = 200
b = 33
c = 500
if a > b and c > a:
  print("both conditions are True")
# Out:
# both conditions are True

# %%
#Or-at least one of the conditions is true
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %%
#Nested if

x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
      print("but not above 20")
# Out:
# Above ten,
# and also above 20!

# %%
#Create a python program that will display above 10, above 20, above 30, above 40
# +5 points
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("above 20,")
    if x > 30:
      print("above 30,")
      if x > 40:
       print("and above 40")
      else:
        print("but not above 40")
    else:
      print("but not above 30")
  else:
      print("but not above 20")
else:
    print("but not above 10")
# Out:
# Above ten,
# above 20,
# above 30,
# and above 40

# %%
#Example 3, WRITE A PROGRAM TO DETERMINE IF THE GRADES ARE:
# +2pts
print("Enter a grade: ")
grade = int(input())

if grade >= 75:
  print("PASSED")
elif grade == 74:
  print("REMEDIAL")
else:
  print("FAILED")
  if grade < 0:
    print("Negative value is not accepted")
# Out:
# Enter a grade:
# 75
# PASSED
